# %%
import cv2
import numpy as np
import random 
from matplotlib import pyplot as plt
from brisque import BRISQUE

# %%
def imshow(title='Image', image = None,size =5):
    w,h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(aspect_ratio*size, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()
    
def score(image):
    obj = BRISQUE(url = False)
    return obj.score(image)

# %%
noisy_image = cv2.imread("C:\\Users\\baksh\\Desktop\\major_project\\images\\Ronaldo3.jpg")
imshow('Noisy Image', noisy_image)
print(noisy_image)
print("Image score of the following image is", score(noisy_image))
# Out:
# [[[ 99  93  98]
#   [102  96 101]
#   [100  94  99]
#   ...
#   [104  98 103]
#   [103  97 102]
#   [105  99 104]]
#
#  [[104  98 103]
#   [100  94  99]
#   [100  94  99]
#   ...
#   [191 185 190]
#   [195 189 194]
#   [102  96 101]]
#
#  [[100  94  99]
#   [193 187 192]
#   [101  95 100]
#   ...
#   [102  96 101]
#   [104  98 103]
#   [106 100 105]]
#
#  ...
#
#  [[113 105 112]
#   [114 106 113]
#   [111 103 110]
#   ...
#   [ 63  48 132]
#   [ 82  64 133]
#   [ 82  64 125]]
#
#  [[112 104 111]
#   [110 102 109]
#   [114 106 113]
#   ...
#   [ 69  53 171]
#   [ 89  70 173]
#   [ 81  61 156]]
#
#  [[109 101 108]
#   [115 107 114]
#   [109 101 108]
#   ...
#   [ 68  50 187]
#   [ 77  56 178]
#   [ 91  68 182]]]
# Image score of the following image is 70.35575783358522

# %%
plt.hist(noisy_image.ravel(),256,[0,256])
plt.ylim([0,10000])
plt.show()

#now seperating the color channels
color = ('b', 'g', 'r')
# seperating the color channels and plotting the histogram 
for i, col in enumerate(color):
    histogram2 = cv2.calcHist([original_image],[i],None,[256],[0,256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])
    plt.ylim([0,10000])
    
plt.show()

# %%
image_denoised1=cv2.fastNlMeansDenoising(noisy_image, None,h=10,templateWindowSize=4,searchWindowSize=21)
image_denoised2=cv2.fastNlMeansDenoising(noisy_image, None,h=26,templateWindowSize=7,searchWindowSize=21)
image_denoised3=cv2.fastNlMeansDenoising(noisy_image, None,h=100,templateWindowSize=20,searchWindowSize=21)
imshow('Denoised Image1', image_denoised1)
print("Image score of the following image is", score(image_denoised1))
imshow('Denoised Image2', image_denoised2)
print("Image score of the following image is", score(image_denoised2))
imshow('Denoised Image3', image_denoised3)
print("Image score of the following image is", score(image_denoised3))
# Out:
# Image score of the following image is 76.5486265923216
# Image score of the following image is 37.92922070498648
# Image score of the following image is 78.17708610128963

# %%
# applying the deblurring filter 
image_gray = image_denoised2
kernel1 = np.array([[-1,-1,-1],[-1,6.5,-1],[-1,1,-1]], np.float32)
kernel2 = np.array([[-1,-1,-1],[-1,6.76,-1],[-1,1,-1]], np.float32)
kernel3 = np.array([[-1,-1,-1],[-1,9.3,-1],[-1,-1,-1]], np.float32)
image_filtered1 = cv2.filter2D(image_gray,-1, kernel1)
image_filtered2 = cv2.filter2D(image_gray,-1, kernel2)
image_filtered3 = cv2.filter2D(image_gray,-1, kernel3)
imshow('Deblurred Image1', image_filtered1)
print("Image score of the following image is", score(image_filtered1))
imshow('Deblurred Image2', image_filtered2)
print("Image score of the following image is", score(image_filtered2))
imshow('Deblurred Image3', image_filtered3)
print("Image score of the following image is", score(image_filtered3))
# Out:
# Image score of the following image is 43.72064780759919
# Image score of the following image is 44.47695173603299
# Image score of the following image is 62.00426590082563

# %%
blur= cv2.GaussianBlur(image_filtered2,(5,5),0)
image_sharp = cv2.subtract(image_filtered2, blur)
image_sharp1  = cv2.addWeighted(image_filtered2,0.8, image_sharp,-2,0)
image_sharp2  = cv2.addWeighted(image_filtered2,1.7, image_sharp,-2,0)
image_sharp3  = cv2.addWeighted(image_filtered2,1.9, image_sharp,-2,0)
#image_sharp = cv2.cvtColor(image_sharp, cv2.COLOR_GRAY2BGR)

imshow("Sharpened Image1", image_sharp1)
print("Image score of the following image is", score(image_sharp1))
imshow("Sharpened Image2", image_sharp2)
print("Image score of the following image is", score(image_sharp2))
imshow("Sharpened Image3", image_sharp3)
print("Image score of the following image is", score(image_sharp3))
# Out:
# Image score of the following image is 42.794079680247904
# Image score of the following image is 27.323569125684543
# Image score of the following image is 52.00001330238544

# %%
alpha1,alpha2,alpha3 = 1.0,1.1,1.3
beta1,beta2,beta3 = 1,1,2
image_enhanced1 = cv2.convertScaleAbs(image_sharp2, alpha = alpha1 , beta = beta1 )
image_enhanced2 = cv2.convertScaleAbs(image_sharp2, alpha = alpha2 , beta = beta2 )
image_enhanced3 = cv2.convertScaleAbs(image_sharp2, alpha = alpha3 , beta = beta3 )
imshow('Image with Enhanced pixels 1', image_enhanced1)
print("Image score of the following image is", score(image_enhanced1))
imshow('Image with Enhanced pixels 2', image_enhanced2)
print("Image score of the following image is", score(image_enhanced2))
imshow('Image with Enhanced pixels 3', image_enhanced3)
print("Image score of the following image is", score(image_enhanced3))
# Out:
# Image score of the following image is 27.35779838722314
# Image score of the following image is 31.017530219560257
# Image score of the following image is 33.634736077400106

# %%
face_classifier = cv2.CascadeClassifier("C:\\Users\\baksh\\Desktop\\Haarcascades\\haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier("C:\\Users\\baksh\\Desktop\\Haarcascades\\haarcascade_eye.xml")

image_to_detect = image_enhanced1
#image = cv2.imread("C:\\Users\\baksh\\Pictures\\IMG_20211204_131154.jpg")
gray = cv2.cvtColor(image_to_detect,cv2.COLOR_BGR2GRAY)


face = face_classifier.detectMultiScale(image_to_detect,1.3,minNeighbors=5,minSize =(3,3)) 

if face == ():
    print("No faces found")

for (x,y,w,h) in face:
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(image_to_detect, 'Face', (x-w, y-h),font,0.5, (0,0, 255),2,cv2.LINE_AA)
    cv2.rectangle(image_to_detect, (x,y), (x+w,y+h),(0,0,255),5)
    roi_gray= gray[y:y+h,x:x+w]
    roi_color=image_to_detect[y:y+h,x:x+w]
    eyes = eye_classifier.detectMultiScale(roi_gray,1.1,minNeighbors =1, minSize = (1,1))
    for (ex,ey, ew, eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,0,255),2)
        if eyes == ():
            print("Eyes Not detected")
    
imshow('Face Detection and Eyes',image_to_detect)
# Out:
# C:\Users\baksh\AppData\Local\Temp\ipykernel_15232\1493914506.py:11: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if face == ():
# C:\Users\baksh\AppData\Local\Temp\ipykernel_15232\1493914506.py:23: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if eyes == ():

# %%
per = (70.35575783358522-27.35779838722314)/70.35575783358522
print(per*100,"% enhancement in the original image")
# Out:
# 61.1150540771184 % enhancement in the original image
